# %%
# !python --version #make sure it is 3.8...if it is not 3.8,run next 2 cells
# Out:
# Python 3.9.16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.9   2         auto mode
#   1            /usr/bin/python3.8   1         manual mode
#   2            /usr/bin/python3.9   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !sudo apt install python3-pip  #run only if next cell does not work
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 24 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.8 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.8 [231 kB]
# Fetched 2,389 kB in 1s (2,658 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 122352 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.8) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.8) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.8) ...
# Setting up python3-pip (20.0.2-5ubuntu1.8) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install streamlit --quiet 
# !pip install spacy_streamlit --quiet 
# !pip install rake_nltk --quiet
# Out:
#      |████████████████████████████████| 9.7 MB 10.1 MB/s
#      |████████████████████████████████| 96 kB 5.1 MB/s
#      |████████████████████████████████| 35.0 MB 19 kB/s
#      |████████████████████████████████| 164 kB 36.9 MB/s
#      |████████████████████████████████| 12.2 MB 47.0 MB/s
#      |████████████████████████████████| 48 kB 4.8 MB/s
#      |████████████████████████████████| 3.3 MB 55.0 MB/s
#      |████████████████████████████████| 238 kB 48.8 MB/s
#      |████████████████████████████████| 813 kB 51.3 MB/s
#      |████████████████████████████████| 1.0 MB 57.4 MB/s
#      |████████████████████████████████| 82 kB 165 kB/s
#      |████████████████████████████████| 62 kB 1.2 MB/s
#      |████████████████████████████████| 4.8 MB 51.9 MB/s
#      |████████████████████████████████| 247 kB 51.9 MB/s
#      |████████████████████████████████| 184 kB 25.1 MB/s
#      |████████████████████████████████| 17.3 MB 18.8 MB/s
#      |████████████████████████████████| 426 kB 76.2 MB/s
#      |████████████████████████████████| 502 kB 50.0 MB/s
#      |████████████████████████████████| 84 kB 2.5 MB/s
#      |████████████████████████████████| 1.1 MB 29.2 MB/s
#      |████████████████████████████████| 90 kB 8.3 MB/s
#      |████████████████████████████████| 133 kB 51.8 MB/s
#      |████████████████████████████████| 55 kB 3.8 MB/s
#      |████████████████████████████████| 74 kB 2.4 MB/s
#      |████████████████████████████████| 61 kB 91 kB/s
#      |████████████████████████████████| 195 kB 24.6 MB/s
#      |████████████████████████████████| 155 kB 66.8 MB/s
#      |████████████████████████████████| 140 kB 78.7 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
#      |████████████████████████████████| 61 kB 7.4 MB/s
#      |████████████████████████████████| 57 kB 5.2 MB/s
#      |████████████████████████████████| 341 kB 52.9 MB/s
#   Building wheel for validators (setup.py) ... done
#      |████████████████████████████████| 6.8 MB 14.8 MB/s
#      |████████████████████████████████| 925 kB 56.9 MB/s
#      |████████████████████████████████| 3.2 MB 43.1 MB/s
#      |████████████████████████████████| 77 kB 3.8 MB/s
#      |████████████████████████████████| 130 kB 82.1 MB/s
#      |████████████████████████████████| 48 kB 4.2 MB/s
#      |████████████████████████████████| 493 kB 31.8 MB/s
#      |████████████████████████████████| 56 kB 3.4 MB/s
#      |████████████████████████████████| 181 kB 59.7 MB/s
#      |████████████████████████████████| 10.2 MB 70.3 MB/s
#      |████████████████████████████████| 1.5 MB 15.9 MB/s
#      |████████████████████████████████| 297 kB 62.3 MB/s
#      |████████████████████████████████| 771 kB 46.9 MB/s

# %%
# %cd 'drive/My Drive/SC'
# Out:
# /content/drive/My Drive/SC

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 1.3 MB/s
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 1.7 MB/s
# Collecting wordcloud==1.8.0
#   Downloading wordcloud-1.8.0-cp38-cp38-manylinux1_x86_64.whl (372 kB)
#      |████████████████████████████████| 372 kB 54.9 MB/s
# Collecting textblob==0.15.3
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 33.6 MB/s
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 46.7 MB/s
# Collecting streamlit==0.69.2
#   Downloading streamlit-0.69.2-py2.py3-none-any.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 40.7 MB/s
# Collecting rake_nltk==1.0.4
#   Downloading rake_nltk-1.0.4.tar.gz (7.6 kB)
# Collecting spacy==2.3.2
#   Downloading spacy-2.3.2-cp38-cp38-manylinux1_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 42.8 MB/s
# Collecting spacy_streamlit==0.1.0
#   Downloading spacy_streamlit-0.1.0-py3-none-any.whl (10 kB)
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 60.4 MB/s
# Collecting joblib==0.17.0
#   Downloading joblib-0.17.0-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 32.6 MB/s
# Collecting sumy==0.8.1
#   Downloading sumy-0.8.1-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.3 MB/s
# Collecting pandas==1.1.3
#   Downloading pandas-1.1.3-cp38-cp38-manylinux1_x86_64.whl (9.3 MB)
#      |████████████████████████████████| 9.3 MB 42.8 MB/s
# Collecting matplotlib==3.3.2
#   Downloading matplotlib-3.3.2-cp38-cp38-manylinux1_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 41.7 MB/s
# Collecting Pillow==8.3.2
#   Downloading Pillow-8.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 40.5 MB/s
# Collecting scikit_learn==0.24.1
#   Downloading scikit_learn-0.24.1-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 1.5 MB/s
# Collecting scipy>=0.18.1
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 20 kB/s
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk==3.5->-r requirements.txt (line 5)) (8.1.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from nltk==3.5->-r requirements.txt (line 5)) (2023.3.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk==3.5->-r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (0.20.0)
# Collecting enum-compat
#   Downloading enum_compat-0.0.3-py3-none-any.whl (1.3 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (6.3.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (4.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (2.8.2)
# Collecting botocore>=1.13.44
#   Downloading botocore-1.29.119-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 40.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (3.1.31)
# Requirement already satisfied: blinker in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (1.6.2)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (4.3)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (3.0.0)
# Collecting boto3
#   Downloading boto3-1.26.119-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 61.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (2.28.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit==0.69.2->-r requirements.txt (line 6)) (0.8.1b0)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#      |████████████████████████████████| 211 kB 43.0 MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==2.3.2->-r requirements.txt (line 8)) (2.0.7)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp38-cp38-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 68.1 MB/s
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy==2.3.2->-r requirements.txt (line 8)) (45.2.0)
# Collecting thinc==7.4.1
#   Downloading thinc-7.4.1-cp38-cp38-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 73.8 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==2.3.2->-r requirements.txt (line 8)) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy==2.3.2->-r requirements.txt (line 8)) (1.0.9)
# Collecting pycountry>=18.2.23
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 35.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting breadability>=0.1.20
#   Downloading breadability-0.1.20.tar.gz (32 kB)
# Collecting docopt<0.7,>=0.6.1
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.8/dist-packages (from pandas==1.1.3->-r requirements.txt (line 13)) (2023.3)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 51.5 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: certifi>=2020.06.20 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.3.2->-r requirements.txt (line 14)) (2022.12.7)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 4.8 MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators->streamlit==0.69.2->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (4.17.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (0.4)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.8/dist-packages (from botocore>=1.13.44->streamlit==0.69.2->-r requirements.txt (line 6)) (1.26.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython->streamlit==0.69.2->-r requirements.txt (line 6)) (4.0.10)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from tzlocal->streamlit==0.69.2->-r requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.8/dist-packages (from tzlocal->streamlit==0.69.2->-r requirements.txt (line 6)) (0.1.0.post0)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.6 MB/s
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==0.69.2->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==0.69.2->-r requirements.txt (line 6)) (3.4)
# Collecting chardet
#   Downloading chardet-5.1.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 53.9 MB/s
# Collecting lxml>=2.0
#   Downloading lxml-4.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 41.7 MB/s
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (5.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython->streamlit==0.69.2->-r requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: tzdata; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from pytz-deprecation-shim->tzlocal->streamlit==0.69.2->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema>=3.0->altair>=3.2.0->streamlit==0.69.2->-r requirements.txt (line 6)) (3.15.0)
# Building wheels for collected packages: nltk, rake-nltk, pycountry, breadability, docopt
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434676 sha256=d1c0cefaf9cae288027940d9a0cbedf214ec9ee5b4b8ae8695b0ffefa2203e85
#   Stored in directory: /root/.cache/pip/wheels/ff/d5/7b/f1fb4e1e1603b2f01c2424dd60fbcc50c12ef918bafc44b155
#   Building wheel for rake-nltk (setup.py) ... done
#   Created wheel for rake-nltk: filename=rake_nltk-1.0.4-py2.py3-none-any.whl size=7819 sha256=8d77f25bb7083d281860ace60bb1c34ab63942ef94ad45c4f4ded38705ff92ec
#   Stored in directory: /root/.cache/pip/wheels/f8/95/fd/23f0be53d1c5d234377f3f85ce063be7d894f0ecdb568389df
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681847 sha256=df1d4a1899d1bf0fb9d51491b6307a303f92a53ec5b38f0505a94721e4705ae2
#   Stored in directory: /root/.cache/pip/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21685 sha256=8713fc09814ac0a386bf0275b7f4d4c637954bf8d723cd54386c577f3c9e05a6
#   Stored in directory: /root/.cache/pip/wheels/5f/0d/0c/2062d8c1758b4b1a2e42b4a63e6660d9ec2ba9463cfee9eeab
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=36c4bc0e662968337a52c7a36ef289dcc88b17cfc725747e9cdff26f5e8b87ef
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built nltk rake-nltk pycountry breadability docopt
# ERROR: confection 0.0.4 has requirement srsly<3.0.0,>=2.4.0, but you'll have srsly 1.0.6 which is incompatible.
# ERROR: scipy 1.10.1 has requirement numpy<1.27.0,>=1.19.5, but you'll have numpy 1.18.5 which is incompatible.
# Installing collected packages: numpy, scipy, gensim, kiwisolver, cycler, Pillow, pyparsing, matplotlib, wordcloud, joblib, nltk, textblob, enum-compat, pandas, jmespath, botocore, astor, s3transfer, boto3, base58, streamlit, rake-nltk, plac, catalogue, srsly, blis, wasabi, thinc, spacy, spacy-streamlit, seaborn, pycountry, chardet, docopt, lxml, breadability, sumy, threadpoolctl, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.21.0
#     Uninstalling streamlit-1.21.0:
#       Successfully uninstalled streamlit-1.21.0
#   Attempting uninstall: rake-nltk
#     Found existing installation: rake-nltk 1.0.6
#     Uninstalling rake-nltk-1.0.6:
#       Successfully uninstalled rake-nltk-1.0.6
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.6
#     Uninstalling srsly-2.4.6:
#       Successfully uninstalled srsly-2.4.6
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.9
#     Uninstalling blis-0.7.9:
#       Successfully uninstalled blis-0.7.9
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.1
#     Uninstalling wasabi-1.1.1:
#       Successfully uninstalled wasabi-1.1.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.9
#     Uninstalling thinc-8.1.9:
#       Successfully uninstalled thinc-8.1.9
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.2
#     Uninstalling spacy-3.5.2:
#       Successfully uninstalled spacy-3.5.2
#   Attempting uninstall: spacy-streamlit
#     Found existing installation: spacy-streamlit 1.0.5
#     Uninstalling spacy-streamlit-1.0.5:
#       Successfully uninstalled spacy-streamlit-1.0.5
# Successfully installed Pillow-8.3.2 astor-0.8.1 base58-2.1.1 blis-0.4.1 boto3-1.26.119 botocore-1.29.119 breadability-0.1.20 catalogue-1.0.2 chardet-5.1.0 cycler-0.11.0 docopt-0.6.2 enum-compat-0.0.3 gensim-3.8.3 jmespath-1.0.1 joblib-0.17.0 kiwisolver-1.4.4 lxml-4.9.2 matplotlib-3.3.2 nltk-3.5 numpy-1.18.5 pandas-1.1.3 plac-1.1.3 pycountry-22.3.5 pyparsing-3.0.9 rake-nltk-1.0.4 s3transfer-0.6.0 scikit-learn-0.24.1 scipy-1.10.1 seaborn-0.11.0 spacy-2.3.2 spacy-streamlit-0.1.0 srsly-1.0.6 streamlit-0.69.2 sumy-0.8.1 textblob-0.15.3 thinc-7.4.1 threadpoolctl-3.1.0 wasabi-0.10.1 wordcloud-1.8.0

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      |████████████████████████████████| 585.9 MB 5.7 kB/s
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      |████████████████████████████████| 22.9 MB 1.2 MB/s
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 53 kB/s
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      |████████████████████████████████| 81 kB 7.8 MB/s
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.20.3)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 63.4 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (45.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.16.0)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.8.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 50.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      |████████████████████████████████| 5.1 MB 44.0 MB/s
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow) (23.1)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.7 MB/s
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 29.8 MB/s
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 56.6 MB/s
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      |████████████████████████████████| 440 kB 76.3 MB/s
# Collecting tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin"
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 42.5 MB/s
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 44.1 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.34.2)
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      |████████████████████████████████| 190 kB 74.1 MB/s
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.0 MB/s
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 82.1 MB/s
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 64.1 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 47.1 MB/s
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.2)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 60.4 MB/s
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.6.0)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 59.2 MB/s
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.2 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 50.9 MB/s
# Building wheels for collected packages: jax
#   Building wheel for jax (PEP 517) ... done
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439691 sha256=d0fed71bf1002d53d2a67b9e533fc23f30bbc55b37b0eb82efb2923a27957d5c
#   Stored in directory: /root/.cache/pip/wheels/45/83/1e/3db22c5e1941c10e41c4f5cdf829b0a358146d4d0733d4a105
# Successfully built jax
# Installing collected packages: libclang, astunparse, numpy, wrapt, absl-py, opt-einsum, ml-dtypes, jax, grpcio, termcolor, flatbuffers, google-pasta, h5py, gast, keras, tensorflow-estimator, tensorflow-io-gcs-filesystem, markdown, pyasn1, rsa, pyasn1-modules, google-auth, tensorboard-data-server, tensorboard-plugin-wit, oauthlib, requests-oauthlib, google-auth-oauthlib, werkzeug, tensorboard, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 h5py-3.8.0 jax-0.4.8 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml-dtypes-0.1.0 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.2 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0 werkzeug-2.2.3 wrapt-1.14.1

# %%
import nltk

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !pip install streamlit==1.8.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting streamlit==1.8.1
#   Downloading streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 9.1 MB/s
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (3.1.31)
# Collecting semver
#   Downloading semver-3.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: validators in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (0.20.0)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (4.2.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (5.3.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (1.0.1)
# Requirement already satisfied: blinker in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (1.6.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (6.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (8.3.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (2.8.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (11.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (1.23.5)
# Collecting click<8.1,>=7.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.1 MB/s
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (1.1.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (0.8.1b0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (3.20.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (4.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (23.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (0.10.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (23.1.0)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (3.0.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (6.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from streamlit==1.8.1) (2.28.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.19->streamlit==1.8.1) (4.0.10)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators->streamlit==1.8.1) (5.1.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.8.1) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.8.1) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.8.1) (4.17.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.8.1) (0.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->streamlit==1.8.1) (1.16.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.21.0->streamlit==1.8.1) (2023.3)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from tzlocal->streamlit==1.8.1) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.8/dist-packages (from tzlocal->streamlit==1.8.1) (0.1.0.post0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit==1.8.1) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==1.8.1) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==1.8.1) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==1.8.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->streamlit==1.8.1) (3.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.8.1) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit==1.8.1) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.8.1) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.8.1) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.8.1) (1.3.10)
# Requirement already satisfied: tzdata; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from pytz-deprecation-shim->tzlocal->streamlit==1.8.1) (2023.3)
# Installing collected packages: semver, click, streamlit
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 0.69.2
#     Uninstalling streamlit-0.69.2:
#       Successfully uninstalled streamlit-0.69.2
# Successfully installed click-8.0.4 semver-3.0.0 streamlit-1.8.1

# %%
#!pip install -U spacy

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 15.5 MB/s
# Requirement already satisfied: spacy>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==2.2.0) (2.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.10.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (45.2.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (7.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.28.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.23.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.8)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.7)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.9)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.1.0)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.0-py3-none-any.whl size=12019121 sha256=44c6e3bbc305dbf79f9f2a3fad5d06dbc25f19c41107a640661993fdcca6321f
#   Stored in directory: /root/.cache/pip/wheels/fc/31/e9/092e6f05b2817c9cb45804a3d1bf2b9bf6575742c01819337c
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.2.0

# %%
# !pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 8.1 MB/s
# Installing collected packages: networkx
# Successfully installed networkx-3.1

# %%
# !pip install 'scipy>=1.8'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.8/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy>=1.8) (1.23.5)

# %%
# !pip install rouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
# !pip install 'gensim==3.8.3'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim==3.8.3 in /usr/local/lib/python3.8/dist-packages (3.8.3)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3) (1.16.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from gensim==3.8.3) (1.23.5)

# %%
# %%writefile webapp.py 

# Import necessary libraries
import joblib
import re
import streamlit as st
import numpy as np
import pandas as pd
import pprint
import warnings
import tempfile
from io import StringIO
from PIL import Image
from rake_nltk import Rake
import spacy
import spacy_streamlit
from collections import Counter

from nltk.tokenize import sent_tokenize
import tensorflow as tf
import en_core_web_sm

from rouge import Rouge 
rouge = Rouge()

#custom imports
import text_summarize as ts
import text_classifier as tc
import text_analysis as nlp

# Warnings ignore 
warnings.filterwarnings(action='ignore')
st.set_option('deprecation.showfileUploaderEncoding', False)
st.set_option('deprecation.showPyplotGlobalUse', False)


# Sidebar options
option = st.sidebar.selectbox('Navigation', 
["Home",
	"Text Summarizer",
 "Text Classifier",
	"N-Gram Analysis",
	"Word Cloud",
	"Summarizer-Classifier"])



if option == 'Home':

	# Describing the Web Application 

	# Title of the application 
	#st.header("Researcher's Friendly Text Analytics Tool\n", )
	st.write(
			"""
				## Researcher's Friendly Text Analytics Tool
			"""
		)

	display = Image.open('display.jpg')
	display = np.array(display)
	st.image(display)
	#st.subheader("Shwetha, Sripradha, Supreetha, Tejaswini")
	#st.subheader("RNS Institute of Technology")
	st.write(
			"""
				## Project Description
				This is a text analytics webapp.
				The various text analytics methods like text summarizer, text classifier, N-gram analyser and a Word Cloud Generator are included.\n
				Text summarizer produces a tiny and crisp version of the corpus while preserving the important information which works based on textrank algorithm.\n
				Text classifier used to classify abstract sentences into the role they play (ie. Objective, Background, Methods, Results and Conclusion) to enable researchers to skim through the literature and dive deeper when necessary.\n
				N-gram analysis identifies all continuous adjacent sequences of words in a given sentence tokens. The N-gram plots can be used to analyse the relevance in the sequence of words.\n
				Word cloud generates the most frequent words in the texts and is a text visualization tool in which words are shown in varying sizes depending on how often they appear in the corpus. An additional feature is the image mask feature where the output can defined in a particular shape based on the image that is provided to the generator.\n
				These methods can be analysed on the corpus by selecting an option from the side bar.
			"""
		)

# Text Summarizer 
elif option == "Text Summarizer": 
	st.header("Text Summarization")
	#st.subheader("Enter the corpus that you want to summarize")
	#st.write("Text summarizer produces a shortened version of the corpus while preserving the important information. The total number of sentences in the shortened version can be chosen using the slider on the left side.")
	text_input = st.text_area("Enter the corpus that you want to summarize", height=200)
	ratio = st.sidebar.slider("Select number of sentences required in summary", min_value=0.0, max_value=1.0, value=0.1, step=0.1)
	sentence_count = len(sent_tokenize(text_input))
	ratio=int(ratio*sentence_count)
	st.write("Number of sentences:", sentence_count)
	
	if st.button("Summarize"):
		out = ts.summarize(text_input,ratio)
		st.write("**Summary Output:**", out)
		st.write("Number of output sentences:", len(sent_tokenize(out)))
		st.write("Rouge Score:",rouge.get_scores(text_input, out))

# Text Classify 
elif option == "Text Classifier": 
	st.header("Text Classification")
	#st.subheader("Enter an unstructured abstract that you want to classify")
	#st.write("Text classifier used to classify abstract sentences into the role they play (ie. Objective, Background, Methods, Results and Conclusion) to enable researchers to skim through the literature and dive deeper when necessary.")
	text_input = st.text_area("Enter an unstructured abstract that you want to classify", height=200)
	if st.button("Classify"):
		out = tc.classify(text_input)
		# st.write(out)

		st.write("**Classified Abstract:**")
		s=""
		for element in out:
			if element=='.':
				st.write(s)
				s=""
			else:
				s=s+element


# N-Gram Analysis Option 
elif option == "N-Gram Analysis":
	
	st.header("N-Gram Analysis")
	#st.subheader("This feature displays the most commonly occuring N-Grams in the entered text")
	#st.write("N-gram is a contiguous sequence of n items from a given sample of text or speech. The items can be phonemes, syllables, letters, words or base pairs according to the application. The n-grams typically are collected from a text or speech corpus. This tool identifies the most commonly occurring n-grams. ")
	# Ask for text or text file
	#st.subheader('Enter text below')
	text = st.text_area('Enter a paragraph', height=200)

	# Parameters
	n = st.sidebar.slider("N for the N-gram", min_value=1, max_value=8, step=1, value=2)
	topk = st.sidebar.slider("Top k most common phrases", min_value=10, max_value=50, step=5, value=10)

	# Add a button 
	if st.button("Generate N-Gram Plot"): 
		# Plot the ngrams
		nlp.plot_ngrams(text, n=n, topk=topk)
		st.pyplot()


# Word Cloud Feature
elif option == "Word Cloud":

	st.header("Word Cloud")
	#st.subheader("This feature generates a word cloud that contains the most frequent words in the entered text")
	#st.write("A word cloud is a data visualization method that forms an integral aspect of text analytics. It is a text representation in which words are shown in varying sizes depending on how often they appear in the corpus. The words with higher frequency are given a bigger font and stand out from the words with lower frequencies. An additional feature is the image mask feature where the output can defined in a particular shape based on the image that is provided to the generator.")
	# Ask for text or text file
	#st.header('Enter text')
	text = st.text_area('Enter a paragraph', height=200)

	# Upload mask image 
	mask = st.file_uploader('Use Image Mask', type = ['jpg'])
	
	if st.button("Generate Wordcloud"): 
		st.write(len(text))
		nlp.create_wordcloud(text, mask)
		st.pyplot()

elif option == "Summarizer-Classifier":
	st.header("Summarizer-Classifier")
	#st.write("This is an integration of text summarizer and classifier. The text summarizer first produces a shortened version of the given corpus. The number of sentences in the shortened version can be chosen as per requirements. The output of the summarizer is fed to the classifier which classifies the sentences in the summarized text into the role they play (ie. Objective, Background, Methods, Results and Conclusion)")
	#st.subheader("Enter the corpus that you want to summarize")
	text_input = st.text_area("Enter a corpus that you want to summarize and classify", height=200)
	ratio = st.sidebar.slider("Select number of sentences required in summary", min_value=0.0, max_value=1.0, value=0.1, step=0.1)
	sentence_count = len(sent_tokenize(text_input))
	ratio=int(ratio*sentence_count)
	st.write("Number of sentences:", sentence_count)
	
	if st.button("Summarize and Classify"):
		int_out = ts.summarize(text_input,ratio)
		fin_out=tc.classify(int_out)
		st.write("**Summary Output:**", int_out)
		st.write("Number of output sentences:", len(sent_tokenize(int_out)))

		st.write("**Classified Abstract:**")
		s=""
		for element in fin_out:
			if element=='.':
				st.write(s)
				s=""
			else:
				s=s+element
# Out:
# Overwriting webapp.py

# %%
# !streamlit run webapp.py & npx localtunnel --port 8501
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.90.188.62:8501
#
# npx: installed 22 in 5.203s
# your url is: https://lovely-oranges-march-34-90-188-62.loca.lt
# 2023-04-25 09:30:43.109668: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 09:30:44.743923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# 2023-04-25 09:30:51.713825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:51.714084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:51.714288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:51.793350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:51.797043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:51.797310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:51.797521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:51.887975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:51.891823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:51.892077: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:51.892264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:51.998718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:52.002348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:52.002604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:52.002787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:52.143864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:52.147518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:52.147763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:52.147938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:52.203374: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:52.203629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:52.203808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:52.267910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:52.271575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:52.271822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:52.272007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:53.956534: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:53.956787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:53.956980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:54.009382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:54.009648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:54.009838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:54.155483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:54.158821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:54.159072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:54.159258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:54.220662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:54.220912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:54.221098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:54.319374: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:54.322710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:54.322964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:54.323152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:54.551932: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:54.555507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:54.555750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:54.555940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.037461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:55.040851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.041117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.041325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.159583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:55.162906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.163151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.163353: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.361336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.361598: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.361775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.429491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:55.431622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.431790: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.431895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.515969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.516156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.516264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.553510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.553694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.553802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.585171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.585368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.585476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.638640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:55.640853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.641018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.641123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:55.705432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:55.705665: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:55.705806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:56.082650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:56.084868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:56.085081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:56.085223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:56.190804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:56.191034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:56.191185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:56.412683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:56.412873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:56.412994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:56.700389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:56.700616: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:56.700758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:56.735828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:56.736049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:56.736189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:57.008928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:57.011112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:57.011319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:57.011455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:57.163485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:57.163670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:57.163776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:57.573804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:57.576037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:57.576207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:57.576357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:57.630314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:57.632441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:57.632601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:57.632703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:57.858053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_reversev2_grad_reversev2_reversev2_axis' with dtype int32 and shape [1]
# 	 [[{{node gradients_reversev2_grad_reversev2_reversev2_axis}}]]
# 2023-04-25 09:30:57.860956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:57.861219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:57.861449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:58.835250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:58.835489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:58.835628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2023-04-25 09:30:59.381036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2023-04-25 09:30:59.381261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2023-04-25 09:30:59.381423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# ...
# 2023-04-25 09:32:22.074 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.074 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.074 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.074 EPOCH - 458 : training on 199 raw words (97 effective words) took 0.0s, 101382 effective words/s
# 2023-04-25 09:32:22.075 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.076 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.076 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.076 EPOCH - 459 : training on 199 raw words (83 effective words) took 0.0s, 93269 effective words/s
# 2023-04-25 09:32:22.080 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.080 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.080 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.080 EPOCH - 460 : training on 199 raw words (87 effective words) took 0.0s, 85231 effective words/s
# 2023-04-25 09:32:22.082 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.082 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.083 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.083 EPOCH - 461 : training on 199 raw words (91 effective words) took 0.0s, 60239 effective words/s
# 2023-04-25 09:32:22.085 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.085 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.086 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.086 EPOCH - 462 : training on 199 raw words (98 effective words) took 0.0s, 78256 effective words/s
# 2023-04-25 09:32:22.087 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.088 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.088 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.088 EPOCH - 463 : training on 199 raw words (90 effective words) took 0.0s, 91493 effective words/s
# 2023-04-25 09:32:22.090 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.090 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.090 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.090 EPOCH - 464 : training on 199 raw words (94 effective words) took 0.0s, 248293 effective words/s
# 2023-04-25 09:32:22.091 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.092 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.092 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.092 EPOCH - 465 : training on 199 raw words (84 effective words) took 0.0s, 84132 effective words/s
# 2023-04-25 09:32:22.094 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.094 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.094 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.094 EPOCH - 466 : training on 199 raw words (87 effective words) took 0.0s, 98533 effective words/s
# 2023-04-25 09:32:22.096 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.096 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.097 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.097 EPOCH - 467 : training on 199 raw words (76 effective words) took 0.0s, 84382 effective words/s
# 2023-04-25 09:32:22.099 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.099 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.099 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.100 EPOCH - 468 : training on 199 raw words (83 effective words) took 0.0s, 76276 effective words/s
# 2023-04-25 09:32:22.102 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.102 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.102 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.102 EPOCH - 469 : training on 199 raw words (85 effective words) took 0.0s, 86657 effective words/s
# 2023-04-25 09:32:22.104 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.104 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.105 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.105 EPOCH - 470 : training on 199 raw words (91 effective words) took 0.0s, 88819 effective words/s
# 2023-04-25 09:32:22.106 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.106 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.107 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.107 EPOCH - 471 : training on 199 raw words (87 effective words) took 0.0s, 71589 effective words/s
# 2023-04-25 09:32:22.108 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.109 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.109 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.110 EPOCH - 472 : training on 199 raw words (85 effective words) took 0.0s, 54450 effective words/s
# 2023-04-25 09:32:22.112 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.112 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.112 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.112 EPOCH - 473 : training on 199 raw words (91 effective words) took 0.0s, 59927 effective words/s
# 2023-04-25 09:32:22.114 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.114 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.114 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.114 EPOCH - 474 : training on 199 raw words (91 effective words) took 0.0s, 99656 effective words/s
# 2023-04-25 09:32:22.116 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.116 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.116 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.116 EPOCH - 475 : training on 199 raw words (96 effective words) took 0.0s, 101615 effective words/s
# 2023-04-25 09:32:22.118 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.118 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.118 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.119 EPOCH - 476 : training on 199 raw words (87 effective words) took 0.0s, 82588 effective words/s
# 2023-04-25 09:32:22.120 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.120 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.120 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.120 EPOCH - 477 : training on 199 raw words (80 effective words) took 0.0s, 98013 effective words/s
# 2023-04-25 09:32:22.122 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.122 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.122 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.122 EPOCH - 478 : training on 199 raw words (84 effective words) took 0.0s, 104133 effective words/s
# 2023-04-25 09:32:22.124 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.124 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.124 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.124 EPOCH - 479 : training on 199 raw words (94 effective words) took 0.0s, 108030 effective words/s
# 2023-04-25 09:32:22.126 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.126 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.126 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.126 EPOCH - 480 : training on 199 raw words (83 effective words) took 0.0s, 99089 effective words/s
# 2023-04-25 09:32:22.127 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.127 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.128 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.128 EPOCH - 481 : training on 199 raw words (93 effective words) took 0.0s, 115939 effective words/s
# 2023-04-25 09:32:22.130 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.130 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.131 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.131 EPOCH - 482 : training on 199 raw words (93 effective words) took 0.0s, 91458 effective words/s
# 2023-04-25 09:32:22.132 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.133 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.133 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.133 EPOCH - 483 : training on 199 raw words (96 effective words) took 0.0s, 90902 effective words/s
# 2023-04-25 09:32:22.135 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.135 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.136 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.136 EPOCH - 484 : training on 199 raw words (74 effective words) took 0.0s, 74437 effective words/s
# 2023-04-25 09:32:22.140 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.140 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.140 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.140 EPOCH - 485 : training on 199 raw words (95 effective words) took 0.0s, 145472 effective words/s
# 2023-04-25 09:32:22.142 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.142 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.142 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.142 EPOCH - 486 : training on 199 raw words (101 effective words) took 0.0s, 104535 effective words/s
# 2023-04-25 09:32:22.144 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.144 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.144 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.144 EPOCH - 487 : training on 199 raw words (96 effective words) took 0.0s, 97455 effective words/s
# 2023-04-25 09:32:22.146 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.147 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.147 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.147 EPOCH - 488 : training on 199 raw words (88 effective words) took 0.0s, 149669 effective words/s
# 2023-04-25 09:32:22.149 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.150 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.150 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.150 EPOCH - 489 : training on 199 raw words (82 effective words) took 0.0s, 82313 effective words/s
# 2023-04-25 09:32:22.152 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.152 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.152 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.152 EPOCH - 490 : training on 199 raw words (87 effective words) took 0.0s, 88448 effective words/s
# 2023-04-25 09:32:22.154 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.154 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.154 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.154 EPOCH - 491 : training on 199 raw words (95 effective words) took 0.0s, 101794 effective words/s
# 2023-04-25 09:32:22.156 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.156 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.156 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.156 EPOCH - 492 : training on 199 raw words (80 effective words) took 0.0s, 79756 effective words/s
# 2023-04-25 09:32:22.158 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.158 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.158 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.158 EPOCH - 493 : training on 199 raw words (89 effective words) took 0.0s, 91390 effective words/s
# 2023-04-25 09:32:22.160 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.160 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.160 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.160 EPOCH - 494 : training on 199 raw words (88 effective words) took 0.0s, 94112 effective words/s
# 2023-04-25 09:32:22.162 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.162 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.162 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.162 EPOCH - 495 : training on 199 raw words (101 effective words) took 0.0s, 110478 effective words/s
# 2023-04-25 09:32:22.164 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.164 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.164 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.164 EPOCH - 496 : training on 199 raw words (96 effective words) took 0.0s, 110843 effective words/s
# 2023-04-25 09:32:22.165 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.165 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.166 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.166 EPOCH - 497 : training on 199 raw words (86 effective words) took 0.0s, 103114 effective words/s
# 2023-04-25 09:32:22.167 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.168 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.168 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.168 EPOCH - 498 : training on 199 raw words (82 effective words) took 0.0s, 125589 effective words/s
# 2023-04-25 09:32:22.170 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.170 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.170 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.170 EPOCH - 499 : training on 199 raw words (85 effective words) took 0.0s, 93672 effective words/s
# 2023-04-25 09:32:22.171 worker thread finished; awaiting finish of 2 more threads
# 2023-04-25 09:32:22.172 worker thread finished; awaiting finish of 1 more threads
# 2023-04-25 09:32:22.172 worker thread finished; awaiting finish of 0 more threads
# 2023-04-25 09:32:22.172 EPOCH - 500 : training on 199 raw words (101 effective words) took 0.0s, 109163 effective words/s
# 2023-04-25 09:32:22.172 training on a 99500 raw words (44138 effective words) took 1.2s, 37035 effective words/s
#   Stopping...
# ^C
